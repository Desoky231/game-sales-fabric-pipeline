# %%
customers = spark.sql("SELECT * FROM lh_silver.profiles")
# Out:
# StatementMeta(, d1080e6b-f16b-4fb3-9b99-2f520d378f49, 4, Finished, Available, Finished)

# %%
customers.write.mode('overwrite').option("overwriteSchema", "true").format("delta").saveAsTable("customers_dim")
# Out:
# StatementMeta(, d1080e6b-f16b-4fb3-9b99-2f520d378f49, 8, Finished, Available, Finished)
